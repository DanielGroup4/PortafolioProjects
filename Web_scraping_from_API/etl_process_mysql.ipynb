# %% [markdown]
# ## Pulling data from an API

# %% [markdown]
# **Importing libraries**
#
# Importando librerias

# %%
import requests
import pandas as pd 
from datetime import datetime

# %% [markdown]
# **Extract data from the Autolist website**
#
# Extraer datos de la pagina web de Autolist

# %%
# User Agent by celaya
# User Agent para celaya
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

# Url Seed
# Url Semilla 
url = "https://www.autolist.com/api/cwv/seo/listings?make=Volkswagen&location=Celaya,%20Gto.&latitude=20.5135374&longitude=-100.8160686&radius=50&page=1"

# # request to the server
# requerimiento al servidor
response = requests.get(url, headers=headers)

# %%
# Check status of response
# Checkar status de response
response
# Out:
# <Response [200]>

# %%
# Create Json Object
# Crear un objeto json

results_json = response.json()
results_json
# Out:
# {'total_results_count': 766,
#  'make_model_name': 'Volkswagen',
#  'trims': [],
#  'ad_info': {'ad_unit': '/19485787/AutoList.com/Search_Results_Page/Volkswagen',
#   'make': 'Volkswagen',
#   'model': None,
#   'page_type': 'srp',
#   'cpo': False,
#   'body_style': None,
#   'year': 2022,
#   'age_type': 'new',
#   'app': 'web',
#   'seller_id': None,
#   'content_url': 'https://production-proxy.autolist.com/listings#latitude=20.5135374&location=Celaya%2C+Gto.&longitude=-100.8160686&make=Volkswagen&page=1&radius=50'},
#  'search_results': [{'available_nationwide': False,
#    'created_at': 1637213661,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/3VW267AJ5GM298864',
#    'vdp_url': '/volkswagen-jetta#vin=3VW267AJ5GM298864',
#    'clickoff_url': 'https://www.carmax.com/car/21376192?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 231723769,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21376192/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--NNHmBTxL--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21376192/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 41.871441,
#    'lon': -87.902115,
#    'year': 2016,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$15,998',
#    'price_unformatted': 15998,
#    'mileage': '72,457 Miles',
#    'mileage_unformatted': 72457,
#    'city': 'Hillside',
#    'state': 'IL',
#    'distance_from_origin': 1656,
#    'dealer_name': 'CarMax Hillside (Eisenhower Expy) - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VW267AJ5GM298864',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VW267AJ5GM298864',
#     'remote_dealer_id': '7146',
#     'dealer_name': 'CarMax Hillside (Eisenhower Expy)',
#     'remote_sku': '21376192',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_hillside',
#     'dealer_uuid': '7f5c202a-fc23-45a4-8a79-578a3406e96f',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1637991251,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWL17AJ9GM377232',
#    'vdp_url': '/volkswagen-jetta#vin=3VWL17AJ9GM377232',
#    'clickoff_url': 'https://www.carmax.com/car/21392875?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232289104,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21392875/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--TwVAt6Qh--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21392875/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 42.950406,
#    'lon': -71.43934,
#    'year': 2016,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$17,998',
#    'price_unformatted': 17998,
#    'mileage': '78,083 Miles',
#    'mileage_unformatted': 78083,
#    'city': 'Manchester',
#    'state': 'NH',
#    'distance_from_origin': 2298,
#    'dealer_name': 'CarMax Manchester - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWL17AJ9GM377232',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWL17AJ9GM377232',
#     'remote_dealer_id': '6107',
#     'dealer_name': 'CarMax Manchester',
#     'remote_sku': '21392875',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_manchester',
#     'dealer_uuid': '444119ef-aa31-4ca0-acc8-51e931c4e929',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.8T SEL PZEV',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1635467321,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWL17AJ3HM216747',
#    'vdp_url': '/volkswagen-jetta#vin=3VWL17AJ3HM216747',
#    'clickoff_url': 'https://www.carmax.com/car/21541173?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 230419192,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21541173/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--pwWhqrE1--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21541173/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 42.13603805033828,
#    'lon': -87.76136051020175,
#    'year': 2017,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$22,998',
#    'price_unformatted': 22998,
#    'mileage': '18,272 Miles',
#    'mileage_unformatted': 18272,
#    'city': 'Glencoe',
#    'state': 'IL',
#    'distance_from_origin': 1676,
#    'dealer_name': 'CarMax Glencoe (Edens Expy) - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWL17AJ3HM216747',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWL17AJ3HM216747',
#     'remote_dealer_id': '7208',
#     'dealer_name': 'CarMax Glencoe (Edens Expy)',
#     'remote_sku': '21541173',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_glencoe',
#     'dealer_uuid': '32bc6f11-31d6-466c-b4a2-cf2c3d1ad8a5',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.8T SEL Premium',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1635485685,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/1VWAT7A33HC009778',
#    'vdp_url': '/volkswagen-passat#vin=1VWAT7A33HC009778',
#    'clickoff_url': 'https://www.carmax.com/car/21419200?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 230445096,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21419200/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--kFBm4njq--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21419200/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 26.157027,
#    'lon': -81.764969,
#    'year': 2017,
#    'make': 'Volkswagen',
#    'model': 'Passat',
#    'model_id': 1645,
#    'display_color': '',
#    'price': '$16,998',
#    'price_unformatted': 16998,
#    'mileage': '77,951 Miles',
#    'mileage_unformatted': 77951,
#    'city': 'Naples',
#    'state': 'FL',
#    'distance_from_origin': 1268,
#    'dealer_name': 'CarMax Naples - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '1VWAT7A33HC009778',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '1VWAT7A33HC009778',
#     'remote_dealer_id': '6036',
#     'dealer_name': 'CarMax Naples',
#     'remote_sku': '21419200',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_naples',
#     'dealer_uuid': '3a2fc375-da8a-4943-bb56-9b7dc71ac4f1',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.8T S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1638337147,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/3VV1B7AXXJM115224',
#    'vdp_url': '/volkswagen-tiguan#vin=3VV1B7AXXJM115224',
#    'clickoff_url': 'https://www.carmax.com/car/20850927?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232489894,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20850927/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--WK5oHuDL--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20850927/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 33.210593,
#    'lon': -96.640006,
#    'year': 2018,
#    'make': 'Volkswagen',
#    'model': 'Tiguan',
#    'model_id': 1657,
#    'display_color': '',
#    'price': '$22,998',
#    'price_unformatted': 22998,
#    'mileage': '29,397 Miles',
#    'mileage_unformatted': 29397,
#    'city': 'Mckinney',
#    'state': 'TX',
#    'distance_from_origin': 913,
#    'dealer_name': 'CarMax McKinney - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VV1B7AXXJM115224',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VV1B7AXXJM115224',
#     'remote_dealer_id': '6094',
#     'dealer_name': 'CarMax McKinney',
#     'remote_sku': '20850927',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_mc_kinney',
#     'dealer_uuid': '81b60b97-af23-4e0f-8ce6-e6ad0e5e8c2c',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1638337135,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/3VW5P7AT0DM804138',
#    'vdp_url': '/volkswagen-beetle#vin=3VW5P7AT0DM804138',
#    'clickoff_url': 'https://www.carmax.com/car/21611564?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232489416,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21611564/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--VA3a69Hd--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21611564/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 31.73517,
#    'lon': -106.319255,
#    'year': 2013,
#    'make': 'Volkswagen',
#    'model': 'Beetle',
#    'model_id': 1658,
#    'display_color': '',
#    'price': '$20,998',
#    'price_unformatted': 20998,
#    'mileage': '51,537 Miles',
#    'mileage_unformatted': 51537,
#    'city': 'El Paso',
#    'state': 'TX',
#    'distance_from_origin': 846,
#    'dealer_name': 'CarMax El Paso - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VW5P7AT0DM804138',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VW5P7AT0DM804138',
#     'remote_dealer_id': '6038',
#     'dealer_name': 'CarMax El Paso',
#     'remote_sku': '21611564',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_el_paso',
#     'dealer_uuid': 'ecec0dc1-230e-4726-965b-01e29951f447',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.5L PZEV',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1636609505,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/1V2NR2CA8JC528380',
#    'vdp_url': '/volkswagen-atlas#vin=1V2NR2CA8JC528380',
#    'clickoff_url': 'https://www.carmax.com/car/21277269?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 231267445,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21277269/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--LSFtU3EK--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21277269/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 35.8665825735939,
#    'lon': -78.53713370982733,
#    'year': 2018,
#    'make': 'Volkswagen',
#    'model': 'Atlas',
#    'model_id': 2173,
#    'display_color': '',
#    'price': '$40,998',
#    'price_unformatted': 40998,
#    'mileage': '48,010 Miles',
#    'mileage_unformatted': 48010,
#    'city': 'Raleigh',
#    'state': 'NC',
#    'distance_from_origin': 1714,
#    'dealer_name': 'CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '1V2NR2CA8JC528380',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '1V2NR2CA8JC528380',
#     'remote_dealer_id': '7282',
#     'dealer_name': 'CarMax Capital Boulevard',
#     'remote_sku': '21277269',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_capital_boulevard',
#     'dealer_uuid': '37dab682-0d2a-4174-b8d0-187d7ede25c7',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'V6 SEL Premium 4Motion',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1638250430,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWH17AU3HM514540',
#    'vdp_url': '/volkswagen-golf+alltrack#vin=3VWH17AU3HM514540',
#    'clickoff_url': 'https://www.carmax.com/car/21327114?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232413515,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21327114/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--NO8f11bB--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21327114/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 39.536456,
#    'lon': -104.777566,
#    'year': 2017,
#    'make': 'Volkswagen',
#    'model': 'Golf Alltrack',
#    'model_id': 2146,
#    'display_color': '',
#    'price': '$26,998',
#    'price_unformatted': 26998,
#    'mileage': '24,824 Miles',
#    'mileage_unformatted': 24824,
#    'city': 'Parker',
#    'state': 'CO',
#    'distance_from_origin': 1335,
#    'dealer_name': 'CarMax Parker - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWH17AU3HM514540',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWH17AU3HM514540',
#     'remote_dealer_id': '6010',
#     'dealer_name': 'CarMax Parker',
#     'remote_sku': '21327114',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_parker',
#     'dealer_uuid': '0bf2bb92-5a5c-4ea9-9b3c-9c9c2f50d9d4',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'TSI SE 4Motion',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1638337147,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/3VWC57BU7KM054979',
#    'vdp_url': '/volkswagen-jetta#vin=3VWC57BU7KM054979',
#    'clickoff_url': 'https://www.carmax.com/car/21743786?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232489904,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21743786/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--A45a9LRL--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21743786/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 37.500874,
#    'lon': -121.966481,
#    'year': 2019,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$20,998',
#    'price_unformatted': 20998,
#    'mileage': '24,699 Miles',
#    'mileage_unformatted': 24699,
#    'city': 'Fremont',
#    'state': 'CA',
#    'distance_from_origin': 1727,
#    'dealer_name': 'CarMax Fremont - Now Open',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWC57BU7KM054979',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWC57BU7KM054979',
#     'remote_dealer_id': '6071',
#     'dealer_name': 'CarMax Fremont',
#     'remote_sku': '21743786',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_fremont',
#     'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1637732059,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWC57BUXKM021331',
#    'vdp_url': '/volkswagen-jetta#vin=3VWC57BUXKM021331',
#    'clickoff_url': 'https://www.carmax.com/car/21522542?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232106560,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21522542/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--2gEO7VxM--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21522542/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 29.61026,
#    'lon': -95.210571,
#    'year': 2019,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$19,998',
#    'price_unformatted': 19998,
#    'mileage': '69,821 Miles',
#    'mileage_unformatted': 69821,
#    'city': 'Houston',
#    'state': 'TX',
#    'distance_from_origin': 719,
#    'dealer_name': 'CarMax Gulf Freeway - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWC57BUXKM021331',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWC57BUXKM021331',
#     'remote_dealer_id': '7116',
#     'dealer_name': 'CarMax Gulf Freeway',
#     'remote_sku': '21522542',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_gulf_freeway',
#     'dealer_uuid': '08e648fc-b5b4-4835-8184-486b4d2a69e6',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1637645960,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/WVWTR7AN8ME002304',
#    'vdp_url': '/volkswagen-arteon#vin=WVWTR7AN8ME002304',
#    'clickoff_url': 'https://www.carmax.com/car/21243662?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232028696,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21243662/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--HAzTaMCX--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21243662/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 38.800437,
#    'lon': -90.607574,
#    'year': 2021,
#    'make': 'Volkswagen',
#    'model': 'Arteon',
#    'model_id': 2306,
#    'display_color': '',
#    'price': '$44,998',
#    'price_unformatted': 44998,
#    'mileage': '7,113 Miles',
#    'mileage_unformatted': 7113,
#    'city': 'St. Peters',
#    'state': 'MO',
#    'distance_from_origin': 1401,
#    'dealer_name': 'CarMax St. Louis Mid Rivers Mall - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': 'WVWTR7AN8ME002304',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': 'WVWTR7AN8ME002304',
#     'remote_dealer_id': '6052',
#     'dealer_name': 'CarMax St. Louis Mid Rivers Mall',
#     'remote_sku': '21243662',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_mid_rivers_mall',
#     'dealer_uuid': '5d853403-ba48-45a9-bb63-10a6b0e65b53',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T SEL Premium R-Line 4Motion',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1637127830,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWN57BU1LM066121',
#    'vdp_url': '/volkswagen-jetta#vin=3VWN57BU1LM066121',
#    'clickoff_url': 'https://www.carmax.com/car/21497509?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 231641072,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21497509/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Ckcgr_5i--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21497509/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 33.87434147442685,
#    'lon': -117.9939564122247,
#    'year': 2020,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$24,998',
#    'price_unformatted': 24998,
#    'mileage': '16,706 Miles',
#    'mileage_unformatted': 16706,
#    'city': 'Buena Park',
#    'state': 'CA',
#    'distance_from_origin': 1398,
#    'dealer_name': 'CarMax Buena Park - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWN57BU1LM066121',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWN57BU1LM066121',
#     'remote_dealer_id': '7129',
#     'dealer_name': 'CarMax Buena Park',
#     'remote_sku': '21497509',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_buena_park',
#     'dealer_uuid': '24c436e9-206e-4838-9f16-34567e28eb77',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T R-Line SULEV',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1632029340,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/WVWVA7AU4KW187501',
#    'vdp_url': '/volkswagen-golf+r#vin=WVWVA7AU4KW187501',
#    'clickoff_url': 'https://www.carmax.com/car/21232426?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 227867446,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21232426/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--fAoXJmtY--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21232426/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 36.14393939975176,
#    'lon': -115.2280381909176,
#    'year': 2019,
#    'make': 'Volkswagen',
#    'model': 'Golf R',
#    'model_id': 1665,
#    'display_color': '',
#    'price': '$44,998',
#    'price_unformatted': 44998,
#    'mileage': '9,886 Miles',
#    'mileage_unformatted': 9886,
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'distance_from_origin': 1387,
#    'dealer_name': 'CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': 'WVWVA7AU4KW187501',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': 'WVWVA7AU4KW187501',
#     'remote_dealer_id': '7244',
#     'dealer_name': 'CarMax West Sahara',
#     'remote_sku': '21232426',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_west_sahara',
#     'dealer_uuid': '66f323f4-16b6-494a-9829-3d181220432d',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'w/DCC and Navigation',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1638337153,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/3VW4T7AJ7HM336369',
#    'vdp_url': '/volkswagen-jetta#vin=3VW4T7AJ7HM336369',
#    'clickoff_url': 'https://www.carmax.com/car/21579010?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232490614,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21579010/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--SDkeD9Wm--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21579010/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 33.6343,
#    'lon': -117.731003,
#    'year': 2017,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$23,998',
#    'price_unformatted': 23998,
#    'mileage': '45,287 Miles',
#    'mileage_unformatted': 45287,
#    'city': 'Irvine',
#    'state': 'CA',
#    'distance_from_origin': 1376,
#    'dealer_name': 'CarMax Irvine - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VW4T7AJ7HM336369',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VW4T7AJ7HM336369',
#     'remote_dealer_id': '7195',
#     'dealer_name': 'CarMax Irvine',
#     'remote_sku': '21579010',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_irvine',
#     'dealer_uuid': 'f11c7a59-6697-4efe-b97f-f742e5b1b2f8',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T GLI',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1637472838,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWG57AU5LM006286',
#    'vdp_url': '/volkswagen-golf#vin=3VWG57AU5LM006286',
#    'clickoff_url': 'https://www.carmax.com/car/21617241?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 231960124,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21617241/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--G1If-nyB--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21617241/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 29.49421179946265,
#    'lon': -95.70422840952467,
#    'year': 2020,
#    'make': 'Volkswagen',
#    'model': 'Golf',
#    'model_id': 1642,
#    'display_color': '',
#    'price': '$25,998',
#    'price_unformatted': 25998,
#    'mileage': '4,492 Miles',
#    'mileage_unformatted': 4492,
#    'city': 'Richmond',
#    'state': 'TX',
#    'distance_from_origin': 697,
#    'dealer_name': 'CarMax Fort Bend - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWG57AU5LM006286',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWG57AU5LM006286',
#     'remote_dealer_id': '6081',
#     'dealer_name': 'CarMax Fort Bend',
#     'remote_sku': '21617241',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_ft_bend',
#     'dealer_uuid': '242e6972-e6db-49dd-bdb6-f308a3bba937',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'TSI',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1635485702,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/WVGAV7AX1HK045664',
#    'vdp_url': '/volkswagen-tiguan#vin=WVGAV7AX1HK045664',
#    'clickoff_url': 'https://www.carmax.com/car/21200423?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 230450210,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21200423/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--OoaJC65m--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21200423/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 25.924963,
#    'lon': -80.302811,
#    'year': 2017,
#    'make': 'Volkswagen',
#    'model': 'Tiguan',
#    'model_id': 1657,
#    'display_color': '',
#    'price': '$21,998',
#    'price_unformatted': 21998,
#    'mileage': '15,920 Miles',
#    'mileage_unformatted': 15920,
#    'city': 'Miami Lakes',
#    'state': 'FL',
#    'distance_from_origin': 1353,
#    'dealer_name': 'CarMax Miami Lakes - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': 'WVGAV7AX1HK045664',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': 'WVGAV7AX1HK045664',
#     'remote_dealer_id': '7198',
#     'dealer_name': 'CarMax Miami Lakes',
#     'remote_sku': '21200423',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_miami_lakes',
#     'dealer_uuid': '7ab86e59-e104-4cbb-84ea-27a0bc9c1026',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T Limited S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1637374456,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/WVWBN7AN3GE515424',
#    'vdp_url': '/volkswagen-cc#vin=WVWBN7AN3GE515424',
#    'clickoff_url': 'https://www.carmax.com/car/21018036?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 231862141,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21018036/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9k8-Nlzy--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21018036/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 29.6874144063821,
#    'lon': -95.51677233949972,
#    'year': 2016,
#    'make': 'Volkswagen',
#    'model': 'CC',
#    'model_id': 1660,
#    'display_color': '',
#    'price': '$20,998',
#    'price_unformatted': 20998,
#    'mileage': '30,261 Miles',
#    'mileage_unformatted': 30261,
#    'city': 'Houston',
#    'state': 'TX',
#    'distance_from_origin': 715,
#    'dealer_name': 'CarMax Southwest Freeway - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': 'WVWBN7AN3GE515424',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': 'WVWBN7AN3GE515424',
#     'remote_dealer_id': '7111',
#     'dealer_name': 'CarMax Southwest Freeway',
#     'remote_sku': '21018036',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_sw_freeway',
#     'dealer_uuid': '57fb2035-3168-4406-ba6f-cab96c18b20b',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T Sport',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1635744824,
#    'recent_price_drop': False,
#    'is_hot': False,
#    'href_target': '/listings/3VWC57BU9KM171298',
#    'vdp_url': '/volkswagen-jetta#vin=3VWC57BU9KM171298',
#    'clickoff_url': 'https://www.carmax.com/car/21490354?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 230651920,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21490354/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--CFMmZjd6--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21490354/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 36.14393939975176,
#    'lon': -115.2280381909176,
#    'year': 2019,
#    'make': 'Volkswagen',
#    'model': 'Jetta',
#    'model_id': 1667,
#    'display_color': '',
#    'price': '$22,998',
#    'price_unformatted': 22998,
#    'mileage': '41,392 Miles',
#    'mileage_unformatted': 41392,
#    'city': 'Las Vegas',
#    'state': 'NV',
#    'distance_from_origin': 1387,
#    'dealer_name': 'CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VWC57BU9KM171298',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VWC57BU9KM171298',
#     'remote_dealer_id': '7244',
#     'dealer_name': 'CarMax West Sahara',
#     'remote_sku': '21490354',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_west_sahara',
#     'dealer_uuid': '66f323f4-16b6-494a-9829-3d181220432d',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '1.4T S',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': None},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1638329571,
#    'recent_price_drop': None,
#    'is_hot': False,
#    'href_target': '/listings/3VV2B7AX8LM134491',
#    'vdp_url': '/volkswagen-tiguan#vin=3VV2B7AX8LM134491',
#    'clickoff_url': 'https://www.carmax.com/car/20936223?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 232484655,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20936223/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--1lu3fw67--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20936223/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 42.26776029832964,
#    'lon': -71.61455938733123,
#    'year': 2020,
#    'make': 'Volkswagen',
#    'model': 'Tiguan',
#    'model_id': 1657,
#    'display_color': '',
#    'price': '$33,998',
#    'price_unformatted': 33998,
#    'mileage': '12,810 Miles',
#    'mileage_unformatted': 12810,
#    'city': 'Westborough',
#    'state': 'MA',
#    'distance_from_origin': 2265,
#    'dealer_name': 'CarMax Westborough - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '3VV2B7AX8LM134491',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '3VV2B7AX8LM134491',
#     'remote_dealer_id': '6067',
#     'dealer_name': 'CarMax Westborough',
#     'remote_sku': '20936223',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_westborough',
#     'dealer_uuid': '68f828c5-9165-4f32-8f17-7ceb8fd9246b',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': '2.0T SE 4Motion',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'fresh'},
#    'quick_picks_eligible': False},
#   {'available_nationwide': False,
#    'created_at': 1636695245,
#    'recent_price_drop': True,
#    'is_hot': False,
#    'href_target': '/listings/1V2MR2CA3LC504874',
#    'vdp_url': '/volkswagen-atlas#vin=1V2MR2CA3LC504874',
#    'clickoff_url': 'https://www.carmax.com/car/21451367?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#    'accepts_leads': True,
#    'open_in_new_window': False,
#    'id': 231345193,
#    'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21451367/1.jpg?width=1024&watermark=LYCG_1a',
#    'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--UxW1NNwH--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21451367/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#    'lat': 39.35256894711024,
#    'lon': -77.37409546105526,
#    'year': 2020,
#    'make': 'Volkswagen',
#    'model': 'Atlas',
#    'model_id': 2173,
#    'display_color': '',
#    'price': '$44,998',
#    'price_unformatted': 44998,
#    'mileage': '12,286 Miles',
#    'mileage_unformatted': 12286,
#    'city': 'Frederick',
#    'state': 'MD',
#    'distance_from_origin': 1903,
#    'dealer_name': 'CarMax Frederick - Now Offering Curbside Pickup',
#    'show_message_box': None,
#    'email_opt_default': True,
#    'show_financing_checkbox': None,
#    'show_new_mileage': False,
#    'show_thankyou_page': False,
#    'show_rsrp': True,
#    'click_off': False,
#    'pre_check_thankyou': True,
#    'cpl_value': 15,
#    'partner_type': 'dealer_direct',
#    'vin': '1V2MR2CA3LC504874',
#    'provider': None,
#    'provider_name': 'carmax',
#    'always_ask_for_zip': True,
#    'listing_id': None,
#    'time_on_market': None,
#    'total_price_change': None,
#    'relative_price_difference': None,
#    'listimate_category': None,
#    'listimate_text': None,
#    'photo_urls': [],
#    'tracking_params': {'id_from_provider': '1V2MR2CA3LC504874',
#     'remote_dealer_id': '6032',
#     'dealer_name': 'CarMax Frederick',
#     'remote_sku': '21451367',
#     'experience': 'national_backfill',
#     'rooftop_unique_name': None,
#     'rooftop_uuid': None,
#     'dealer_unique_name': 'carmax_frederick',
#     'dealer_uuid': '1ad00678-fb36-4790-93ab-0a734bb51b40',
#     'dealer_group_unique_name': 'carmax',
#     'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#    'trim': 'V6 SEL 4Motion',
#    'provider_id': 146,
#    'provider_group_id': 149,
#    'experience': 'local_if_nearby',
#    'regional': True,
#    'badges': {'position0': None, 'position1': 'price_drop'},
#    'quick_picks_eligible': False}],
#  'html': {'search_results': '<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/volkswagen-jetta#vin=3VW267AJ5GM298864"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--NNHmBTxL--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21376192/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a)\' title=\'used 2016 Volkswagen Jetta 1.4T S Silver 3VW267AJ5GM298864\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2016 Volkswagen Jetta 1.4T S</div>\n<div class=\'subtext\'>\n72,457 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Transfer Available</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$15,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $231/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/volkswagen-jetta#vin=3VWL17AJ9GM377232"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' style=\'background-image: url(https://images.autolist.com/image/fetch/s--TwVAt6Qh--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21392875/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a)\' title=\'used 2016 Volkswagen Jetta 1.8T SEL PZEV Red 3VWL17AJ9GM377232\'></div>\n</div>\n<div class=\'badges-container\'>\n<div class=\'outer-container\'>\n<div class=\'\' data-spot=\'0\'>\n\n</div>\n<div class=\'\' data-spot=\'1\'>\n\n</div>\n</div>\n</div>\n</div>\n<div class=\'details\'>\n<h3 class=\'AL-vehicle-primary-details -small-sm -small-xs\'>\n<div class=\'description\'>\n<div class=\'headline\'>2016 Volkswagen Jetta 1.8T SEL PZEV</div>\n<div class=\'subtext\'>\n78,083 Miles\n<span class=\'divider\'>\n|\n</span>\n<span class=\'location\'>Transfer Available</span>\n</div>\n</div>\n<div class=\'pricing\'>\n<div class=\'headline\'>$17,998</div>\n<div class=\'monthly-payment\' data-menu data-monthly-payment>\n<span class=\'info-link\' href=\'javascript:void(0);\'>\nest. $259/mo\n<i></i>\n</span>\n</div>\n</div>\n</h3>\n<div class=\'AL-vehicle-secondary-details -small-sm -small-xs\' data-menu>\n<div class=\'action\'>\n<span class=\'\' data-action=\'track price\'>\nTrack Price\n</span>\n<span class=\'popout-item\' data-action=\'check availability\'>\nCheck Availability\n</span>\n</div>\n</div>\n</div>\n</a>\n<a class="AL-vehicle-item -small-md -stacked-sm -stacked-xs -popout-action" href="/volkswagen-jetta#vin=3VWL17AJ3HM216747"><div class=\'photo\'>\n<div class=\'AL-vehicle-photo\'>\n<div class=\'viewed-overlay hidden\'></div>\n<div class=\'photo-overlay\'></div>\n<div class=\'overlay-menu\' data-menu>\n<div class=\'-favorite -results-gtsm item\' data-action=\'favorite\'></div>\n</div>\n<div class=\'photo\' data-background-image=\'https://images.autolist.com/image/fetch/s--pwWhqrE1--/c_fill,f_auto, ...
#   'pagination': '<ul><li class="previous disabled"><a>Previous</a></li><li class="selected"><a>1</a></li><li data-page="2"><a>2</a></li><li data-page="3"><a>3</a></li><li data-page="4"><a>...</a></li><li data-page="37"><a>37</a></li><li data-page="38"><a>38</a></li><li data-page="2" class="next"><a>Next</a></li></ul>'}}

# %%
type(results_json)
# Out:
# dict

# %%
# Output Keys
# claves o keys de salida
results_json.keys()
# Out:
# dict_keys(['total_results_count', 'make_model_name', 'trims', 'ad_info', 'search_results', 'html'])

# %% [markdown]
# **Find the Data**
#
# Encontrando los datos
#
# * model (modelo)
# * mileage (kilometraje)
# * year (año)
# * dealer_name (nombre de distribuidor)
# * price (precio)

# %%
# checking 'search_results' data type
# revisando tipo de datos de 'search_results' 
type(results_json['search_results'])
# Out:
# list

# %%
# checking that the list contains the necessary information
# revisando que la lista contenga los datos necesarios
results_json['search_results']
# Out:
# [{'available_nationwide': False,
#   'created_at': 1637213661,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/3VW267AJ5GM298864',
#   'vdp_url': '/volkswagen-jetta#vin=3VW267AJ5GM298864',
#   'clickoff_url': 'https://www.carmax.com/car/21376192?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 231723769,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21376192/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--NNHmBTxL--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21376192/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 41.871441,
#   'lon': -87.902115,
#   'year': 2016,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$15,998',
#   'price_unformatted': 15998,
#   'mileage': '72,457 Miles',
#   'mileage_unformatted': 72457,
#   'city': 'Hillside',
#   'state': 'IL',
#   'distance_from_origin': 1656,
#   'dealer_name': 'CarMax Hillside (Eisenhower Expy) - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VW267AJ5GM298864',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VW267AJ5GM298864',
#    'remote_dealer_id': '7146',
#    'dealer_name': 'CarMax Hillside (Eisenhower Expy)',
#    'remote_sku': '21376192',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_hillside',
#    'dealer_uuid': '7f5c202a-fc23-45a4-8a79-578a3406e96f',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1637991251,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWL17AJ9GM377232',
#   'vdp_url': '/volkswagen-jetta#vin=3VWL17AJ9GM377232',
#   'clickoff_url': 'https://www.carmax.com/car/21392875?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232289104,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21392875/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--TwVAt6Qh--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21392875/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 42.950406,
#   'lon': -71.43934,
#   'year': 2016,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$17,998',
#   'price_unformatted': 17998,
#   'mileage': '78,083 Miles',
#   'mileage_unformatted': 78083,
#   'city': 'Manchester',
#   'state': 'NH',
#   'distance_from_origin': 2298,
#   'dealer_name': 'CarMax Manchester - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWL17AJ9GM377232',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWL17AJ9GM377232',
#    'remote_dealer_id': '6107',
#    'dealer_name': 'CarMax Manchester',
#    'remote_sku': '21392875',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_manchester',
#    'dealer_uuid': '444119ef-aa31-4ca0-acc8-51e931c4e929',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.8T SEL PZEV',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1635467321,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWL17AJ3HM216747',
#   'vdp_url': '/volkswagen-jetta#vin=3VWL17AJ3HM216747',
#   'clickoff_url': 'https://www.carmax.com/car/21541173?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 230419192,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21541173/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--pwWhqrE1--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21541173/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 42.13603805033828,
#   'lon': -87.76136051020175,
#   'year': 2017,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$22,998',
#   'price_unformatted': 22998,
#   'mileage': '18,272 Miles',
#   'mileage_unformatted': 18272,
#   'city': 'Glencoe',
#   'state': 'IL',
#   'distance_from_origin': 1676,
#   'dealer_name': 'CarMax Glencoe (Edens Expy) - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWL17AJ3HM216747',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWL17AJ3HM216747',
#    'remote_dealer_id': '7208',
#    'dealer_name': 'CarMax Glencoe (Edens Expy)',
#    'remote_sku': '21541173',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_glencoe',
#    'dealer_uuid': '32bc6f11-31d6-466c-b4a2-cf2c3d1ad8a5',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.8T SEL Premium',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1635485685,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/1VWAT7A33HC009778',
#   'vdp_url': '/volkswagen-passat#vin=1VWAT7A33HC009778',
#   'clickoff_url': 'https://www.carmax.com/car/21419200?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 230445096,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21419200/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--kFBm4njq--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21419200/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 26.157027,
#   'lon': -81.764969,
#   'year': 2017,
#   'make': 'Volkswagen',
#   'model': 'Passat',
#   'model_id': 1645,
#   'display_color': '',
#   'price': '$16,998',
#   'price_unformatted': 16998,
#   'mileage': '77,951 Miles',
#   'mileage_unformatted': 77951,
#   'city': 'Naples',
#   'state': 'FL',
#   'distance_from_origin': 1268,
#   'dealer_name': 'CarMax Naples - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '1VWAT7A33HC009778',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '1VWAT7A33HC009778',
#    'remote_dealer_id': '6036',
#    'dealer_name': 'CarMax Naples',
#    'remote_sku': '21419200',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_naples',
#    'dealer_uuid': '3a2fc375-da8a-4943-bb56-9b7dc71ac4f1',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.8T S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1638337147,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/3VV1B7AXXJM115224',
#   'vdp_url': '/volkswagen-tiguan#vin=3VV1B7AXXJM115224',
#   'clickoff_url': 'https://www.carmax.com/car/20850927?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232489894,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20850927/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--WK5oHuDL--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20850927/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 33.210593,
#   'lon': -96.640006,
#   'year': 2018,
#   'make': 'Volkswagen',
#   'model': 'Tiguan',
#   'model_id': 1657,
#   'display_color': '',
#   'price': '$22,998',
#   'price_unformatted': 22998,
#   'mileage': '29,397 Miles',
#   'mileage_unformatted': 29397,
#   'city': 'Mckinney',
#   'state': 'TX',
#   'distance_from_origin': 913,
#   'dealer_name': 'CarMax McKinney - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VV1B7AXXJM115224',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VV1B7AXXJM115224',
#    'remote_dealer_id': '6094',
#    'dealer_name': 'CarMax McKinney',
#    'remote_sku': '20850927',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_mc_kinney',
#    'dealer_uuid': '81b60b97-af23-4e0f-8ce6-e6ad0e5e8c2c',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1638337135,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/3VW5P7AT0DM804138',
#   'vdp_url': '/volkswagen-beetle#vin=3VW5P7AT0DM804138',
#   'clickoff_url': 'https://www.carmax.com/car/21611564?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232489416,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21611564/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--VA3a69Hd--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21611564/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 31.73517,
#   'lon': -106.319255,
#   'year': 2013,
#   'make': 'Volkswagen',
#   'model': 'Beetle',
#   'model_id': 1658,
#   'display_color': '',
#   'price': '$20,998',
#   'price_unformatted': 20998,
#   'mileage': '51,537 Miles',
#   'mileage_unformatted': 51537,
#   'city': 'El Paso',
#   'state': 'TX',
#   'distance_from_origin': 846,
#   'dealer_name': 'CarMax El Paso - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VW5P7AT0DM804138',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VW5P7AT0DM804138',
#    'remote_dealer_id': '6038',
#    'dealer_name': 'CarMax El Paso',
#    'remote_sku': '21611564',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_el_paso',
#    'dealer_uuid': 'ecec0dc1-230e-4726-965b-01e29951f447',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.5L PZEV',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1636609505,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/1V2NR2CA8JC528380',
#   'vdp_url': '/volkswagen-atlas#vin=1V2NR2CA8JC528380',
#   'clickoff_url': 'https://www.carmax.com/car/21277269?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 231267445,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21277269/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--LSFtU3EK--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21277269/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 35.8665825735939,
#   'lon': -78.53713370982733,
#   'year': 2018,
#   'make': 'Volkswagen',
#   'model': 'Atlas',
#   'model_id': 2173,
#   'display_color': '',
#   'price': '$40,998',
#   'price_unformatted': 40998,
#   'mileage': '48,010 Miles',
#   'mileage_unformatted': 48010,
#   'city': 'Raleigh',
#   'state': 'NC',
#   'distance_from_origin': 1714,
#   'dealer_name': 'CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '1V2NR2CA8JC528380',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '1V2NR2CA8JC528380',
#    'remote_dealer_id': '7282',
#    'dealer_name': 'CarMax Capital Boulevard',
#    'remote_sku': '21277269',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_capital_boulevard',
#    'dealer_uuid': '37dab682-0d2a-4174-b8d0-187d7ede25c7',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'V6 SEL Premium 4Motion',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1638250430,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWH17AU3HM514540',
#   'vdp_url': '/volkswagen-golf+alltrack#vin=3VWH17AU3HM514540',
#   'clickoff_url': 'https://www.carmax.com/car/21327114?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232413515,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21327114/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--NO8f11bB--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21327114/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 39.536456,
#   'lon': -104.777566,
#   'year': 2017,
#   'make': 'Volkswagen',
#   'model': 'Golf Alltrack',
#   'model_id': 2146,
#   'display_color': '',
#   'price': '$26,998',
#   'price_unformatted': 26998,
#   'mileage': '24,824 Miles',
#   'mileage_unformatted': 24824,
#   'city': 'Parker',
#   'state': 'CO',
#   'distance_from_origin': 1335,
#   'dealer_name': 'CarMax Parker - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWH17AU3HM514540',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWH17AU3HM514540',
#    'remote_dealer_id': '6010',
#    'dealer_name': 'CarMax Parker',
#    'remote_sku': '21327114',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_parker',
#    'dealer_uuid': '0bf2bb92-5a5c-4ea9-9b3c-9c9c2f50d9d4',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'TSI SE 4Motion',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1638337147,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/3VWC57BU7KM054979',
#   'vdp_url': '/volkswagen-jetta#vin=3VWC57BU7KM054979',
#   'clickoff_url': 'https://www.carmax.com/car/21743786?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232489904,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21743786/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--A45a9LRL--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21743786/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 37.500874,
#   'lon': -121.966481,
#   'year': 2019,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$20,998',
#   'price_unformatted': 20998,
#   'mileage': '24,699 Miles',
#   'mileage_unformatted': 24699,
#   'city': 'Fremont',
#   'state': 'CA',
#   'distance_from_origin': 1727,
#   'dealer_name': 'CarMax Fremont - Now Open',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWC57BU7KM054979',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWC57BU7KM054979',
#    'remote_dealer_id': '6071',
#    'dealer_name': 'CarMax Fremont',
#    'remote_sku': '21743786',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_fremont',
#    'dealer_uuid': '816ccf79-c17e-4c9c-80e4-0c47ab4722d6',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1637732059,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWC57BUXKM021331',
#   'vdp_url': '/volkswagen-jetta#vin=3VWC57BUXKM021331',
#   'clickoff_url': 'https://www.carmax.com/car/21522542?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232106560,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21522542/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--2gEO7VxM--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21522542/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 29.61026,
#   'lon': -95.210571,
#   'year': 2019,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$19,998',
#   'price_unformatted': 19998,
#   'mileage': '69,821 Miles',
#   'mileage_unformatted': 69821,
#   'city': 'Houston',
#   'state': 'TX',
#   'distance_from_origin': 719,
#   'dealer_name': 'CarMax Gulf Freeway - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWC57BUXKM021331',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWC57BUXKM021331',
#    'remote_dealer_id': '7116',
#    'dealer_name': 'CarMax Gulf Freeway',
#    'remote_sku': '21522542',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_gulf_freeway',
#    'dealer_uuid': '08e648fc-b5b4-4835-8184-486b4d2a69e6',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1637645960,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/WVWTR7AN8ME002304',
#   'vdp_url': '/volkswagen-arteon#vin=WVWTR7AN8ME002304',
#   'clickoff_url': 'https://www.carmax.com/car/21243662?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232028696,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21243662/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--HAzTaMCX--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21243662/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 38.800437,
#   'lon': -90.607574,
#   'year': 2021,
#   'make': 'Volkswagen',
#   'model': 'Arteon',
#   'model_id': 2306,
#   'display_color': '',
#   'price': '$44,998',
#   'price_unformatted': 44998,
#   'mileage': '7,113 Miles',
#   'mileage_unformatted': 7113,
#   'city': 'St. Peters',
#   'state': 'MO',
#   'distance_from_origin': 1401,
#   'dealer_name': 'CarMax St. Louis Mid Rivers Mall - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': 'WVWTR7AN8ME002304',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': 'WVWTR7AN8ME002304',
#    'remote_dealer_id': '6052',
#    'dealer_name': 'CarMax St. Louis Mid Rivers Mall',
#    'remote_sku': '21243662',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_mid_rivers_mall',
#    'dealer_uuid': '5d853403-ba48-45a9-bb63-10a6b0e65b53',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T SEL Premium R-Line 4Motion',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1637127830,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWN57BU1LM066121',
#   'vdp_url': '/volkswagen-jetta#vin=3VWN57BU1LM066121',
#   'clickoff_url': 'https://www.carmax.com/car/21497509?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 231641072,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21497509/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--Ckcgr_5i--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21497509/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 33.87434147442685,
#   'lon': -117.9939564122247,
#   'year': 2020,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$24,998',
#   'price_unformatted': 24998,
#   'mileage': '16,706 Miles',
#   'mileage_unformatted': 16706,
#   'city': 'Buena Park',
#   'state': 'CA',
#   'distance_from_origin': 1398,
#   'dealer_name': 'CarMax Buena Park - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWN57BU1LM066121',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWN57BU1LM066121',
#    'remote_dealer_id': '7129',
#    'dealer_name': 'CarMax Buena Park',
#    'remote_sku': '21497509',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_buena_park',
#    'dealer_uuid': '24c436e9-206e-4838-9f16-34567e28eb77',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T R-Line SULEV',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1632029340,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/WVWVA7AU4KW187501',
#   'vdp_url': '/volkswagen-golf+r#vin=WVWVA7AU4KW187501',
#   'clickoff_url': 'https://www.carmax.com/car/21232426?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 227867446,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21232426/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--fAoXJmtY--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21232426/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 36.14393939975176,
#   'lon': -115.2280381909176,
#   'year': 2019,
#   'make': 'Volkswagen',
#   'model': 'Golf R',
#   'model_id': 1665,
#   'display_color': '',
#   'price': '$44,998',
#   'price_unformatted': 44998,
#   'mileage': '9,886 Miles',
#   'mileage_unformatted': 9886,
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'distance_from_origin': 1387,
#   'dealer_name': 'CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': 'WVWVA7AU4KW187501',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': 'WVWVA7AU4KW187501',
#    'remote_dealer_id': '7244',
#    'dealer_name': 'CarMax West Sahara',
#    'remote_sku': '21232426',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_west_sahara',
#    'dealer_uuid': '66f323f4-16b6-494a-9829-3d181220432d',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'w/DCC and Navigation',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1638337153,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/3VW4T7AJ7HM336369',
#   'vdp_url': '/volkswagen-jetta#vin=3VW4T7AJ7HM336369',
#   'clickoff_url': 'https://www.carmax.com/car/21579010?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232490614,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21579010/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--SDkeD9Wm--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21579010/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 33.6343,
#   'lon': -117.731003,
#   'year': 2017,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$23,998',
#   'price_unformatted': 23998,
#   'mileage': '45,287 Miles',
#   'mileage_unformatted': 45287,
#   'city': 'Irvine',
#   'state': 'CA',
#   'distance_from_origin': 1376,
#   'dealer_name': 'CarMax Irvine - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VW4T7AJ7HM336369',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VW4T7AJ7HM336369',
#    'remote_dealer_id': '7195',
#    'dealer_name': 'CarMax Irvine',
#    'remote_sku': '21579010',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_irvine',
#    'dealer_uuid': 'f11c7a59-6697-4efe-b97f-f742e5b1b2f8',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T GLI',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1637472838,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWG57AU5LM006286',
#   'vdp_url': '/volkswagen-golf#vin=3VWG57AU5LM006286',
#   'clickoff_url': 'https://www.carmax.com/car/21617241?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 231960124,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21617241/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--G1If-nyB--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21617241/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 29.49421179946265,
#   'lon': -95.70422840952467,
#   'year': 2020,
#   'make': 'Volkswagen',
#   'model': 'Golf',
#   'model_id': 1642,
#   'display_color': '',
#   'price': '$25,998',
#   'price_unformatted': 25998,
#   'mileage': '4,492 Miles',
#   'mileage_unformatted': 4492,
#   'city': 'Richmond',
#   'state': 'TX',
#   'distance_from_origin': 697,
#   'dealer_name': 'CarMax Fort Bend - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWG57AU5LM006286',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWG57AU5LM006286',
#    'remote_dealer_id': '6081',
#    'dealer_name': 'CarMax Fort Bend',
#    'remote_sku': '21617241',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_ft_bend',
#    'dealer_uuid': '242e6972-e6db-49dd-bdb6-f308a3bba937',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'TSI',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1635485702,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/WVGAV7AX1HK045664',
#   'vdp_url': '/volkswagen-tiguan#vin=WVGAV7AX1HK045664',
#   'clickoff_url': 'https://www.carmax.com/car/21200423?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 230450210,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21200423/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--OoaJC65m--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21200423/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 25.924963,
#   'lon': -80.302811,
#   'year': 2017,
#   'make': 'Volkswagen',
#   'model': 'Tiguan',
#   'model_id': 1657,
#   'display_color': '',
#   'price': '$21,998',
#   'price_unformatted': 21998,
#   'mileage': '15,920 Miles',
#   'mileage_unformatted': 15920,
#   'city': 'Miami Lakes',
#   'state': 'FL',
#   'distance_from_origin': 1353,
#   'dealer_name': 'CarMax Miami Lakes - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': 'WVGAV7AX1HK045664',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': 'WVGAV7AX1HK045664',
#    'remote_dealer_id': '7198',
#    'dealer_name': 'CarMax Miami Lakes',
#    'remote_sku': '21200423',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_miami_lakes',
#    'dealer_uuid': '7ab86e59-e104-4cbb-84ea-27a0bc9c1026',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T Limited S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1637374456,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/WVWBN7AN3GE515424',
#   'vdp_url': '/volkswagen-cc#vin=WVWBN7AN3GE515424',
#   'clickoff_url': 'https://www.carmax.com/car/21018036?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 231862141,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21018036/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--9k8-Nlzy--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21018036/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 29.6874144063821,
#   'lon': -95.51677233949972,
#   'year': 2016,
#   'make': 'Volkswagen',
#   'model': 'CC',
#   'model_id': 1660,
#   'display_color': '',
#   'price': '$20,998',
#   'price_unformatted': 20998,
#   'mileage': '30,261 Miles',
#   'mileage_unformatted': 30261,
#   'city': 'Houston',
#   'state': 'TX',
#   'distance_from_origin': 715,
#   'dealer_name': 'CarMax Southwest Freeway - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': 'WVWBN7AN3GE515424',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': 'WVWBN7AN3GE515424',
#    'remote_dealer_id': '7111',
#    'dealer_name': 'CarMax Southwest Freeway',
#    'remote_sku': '21018036',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_sw_freeway',
#    'dealer_uuid': '57fb2035-3168-4406-ba6f-cab96c18b20b',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T Sport',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1635744824,
#   'recent_price_drop': False,
#   'is_hot': False,
#   'href_target': '/listings/3VWC57BU9KM171298',
#   'vdp_url': '/volkswagen-jetta#vin=3VWC57BU9KM171298',
#   'clickoff_url': 'https://www.carmax.com/car/21490354?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 230651920,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21490354/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--CFMmZjd6--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21490354/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 36.14393939975176,
#   'lon': -115.2280381909176,
#   'year': 2019,
#   'make': 'Volkswagen',
#   'model': 'Jetta',
#   'model_id': 1667,
#   'display_color': '',
#   'price': '$22,998',
#   'price_unformatted': 22998,
#   'mileage': '41,392 Miles',
#   'mileage_unformatted': 41392,
#   'city': 'Las Vegas',
#   'state': 'NV',
#   'distance_from_origin': 1387,
#   'dealer_name': 'CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VWC57BU9KM171298',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VWC57BU9KM171298',
#    'remote_dealer_id': '7244',
#    'dealer_name': 'CarMax West Sahara',
#    'remote_sku': '21490354',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_west_sahara',
#    'dealer_uuid': '66f323f4-16b6-494a-9829-3d181220432d',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '1.4T S',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': None},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1638329571,
#   'recent_price_drop': None,
#   'is_hot': False,
#   'href_target': '/listings/3VV2B7AX8LM134491',
#   'vdp_url': '/volkswagen-tiguan#vin=3VV2B7AX8LM134491',
#   'clickoff_url': 'https://www.carmax.com/car/20936223?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 232484655,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/20936223/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--1lu3fw67--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/20936223/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 42.26776029832964,
#   'lon': -71.61455938733123,
#   'year': 2020,
#   'make': 'Volkswagen',
#   'model': 'Tiguan',
#   'model_id': 1657,
#   'display_color': '',
#   'price': '$33,998',
#   'price_unformatted': 33998,
#   'mileage': '12,810 Miles',
#   'mileage_unformatted': 12810,
#   'city': 'Westborough',
#   'state': 'MA',
#   'distance_from_origin': 2265,
#   'dealer_name': 'CarMax Westborough - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '3VV2B7AX8LM134491',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '3VV2B7AX8LM134491',
#    'remote_dealer_id': '6067',
#    'dealer_name': 'CarMax Westborough',
#    'remote_sku': '20936223',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_westborough',
#    'dealer_uuid': '68f828c5-9165-4f32-8f17-7ceb8fd9246b',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': '2.0T SE 4Motion',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'fresh'},
#   'quick_picks_eligible': False},
#  {'available_nationwide': False,
#   'created_at': 1636695245,
#   'recent_price_drop': True,
#   'is_hot': False,
#   'href_target': '/listings/1V2MR2CA3LC504874',
#   'vdp_url': '/volkswagen-atlas#vin=1V2MR2CA3LC504874',
#   'clickoff_url': 'https://www.carmax.com/car/21451367?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#   'accepts_leads': True,
#   'open_in_new_window': False,
#   'id': 231345193,
#   'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21451367/1.jpg?width=1024&watermark=LYCG_1a',
#   'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--UxW1NNwH--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21451367/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#   'lat': 39.35256894711024,
#   'lon': -77.37409546105526,
#   'year': 2020,
#   'make': 'Volkswagen',
#   'model': 'Atlas',
#   'model_id': 2173,
#   'display_color': '',
#   'price': '$44,998',
#   'price_unformatted': 44998,
#   'mileage': '12,286 Miles',
#   'mileage_unformatted': 12286,
#   'city': 'Frederick',
#   'state': 'MD',
#   'distance_from_origin': 1903,
#   'dealer_name': 'CarMax Frederick - Now Offering Curbside Pickup',
#   'show_message_box': None,
#   'email_opt_default': True,
#   'show_financing_checkbox': None,
#   'show_new_mileage': False,
#   'show_thankyou_page': False,
#   'show_rsrp': True,
#   'click_off': False,
#   'pre_check_thankyou': True,
#   'cpl_value': 15,
#   'partner_type': 'dealer_direct',
#   'vin': '1V2MR2CA3LC504874',
#   'provider': None,
#   'provider_name': 'carmax',
#   'always_ask_for_zip': True,
#   'listing_id': None,
#   'time_on_market': None,
#   'total_price_change': None,
#   'relative_price_difference': None,
#   'listimate_category': None,
#   'listimate_text': None,
#   'photo_urls': [],
#   'tracking_params': {'id_from_provider': '1V2MR2CA3LC504874',
#    'remote_dealer_id': '6032',
#    'dealer_name': 'CarMax Frederick',
#    'remote_sku': '21451367',
#    'experience': 'national_backfill',
#    'rooftop_unique_name': None,
#    'rooftop_uuid': None,
#    'dealer_unique_name': 'carmax_frederick',
#    'dealer_uuid': '1ad00678-fb36-4790-93ab-0a734bb51b40',
#    'dealer_group_unique_name': 'carmax',
#    'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#   'trim': 'V6 SEL 4Motion',
#   'provider_id': 146,
#   'provider_group_id': 149,
#   'experience': 'local_if_nearby',
#   'regional': True,
#   'badges': {'position0': None, 'position1': 'price_drop'},
#   'quick_picks_eligible': False}]

# %%
# checking the number of items in the list
# revisando el numero de elementos en la lista
len(results_json['search_results'])
# Out:
# 20

# %%
result_items = results_json['search_results']

# %%
# starting point for the first item in the list (dictionary)
# punto de partida para el primer elemento de la lista (diccionario)
results_json['search_results'][0]
# Out:
# {'available_nationwide': False,
#  'created_at': 1637213661,
#  'recent_price_drop': None,
#  'is_hot': False,
#  'href_target': '/listings/3VW267AJ5GM298864',
#  'vdp_url': '/volkswagen-jetta#vin=3VW267AJ5GM298864',
#  'clickoff_url': 'https://www.carmax.com/car/21376192?adcode=ALST&utm_campaign=LG_OC&utm_source=LG_OC_ALST&utm_medium=OC&utm_content=carpage ',
#  'accepts_leads': True,
#  'open_in_new_window': False,
#  'id': 231723769,
#  'primary_photo_url': 'https://img2.carmax.com/img/vehicles/21376192/1.jpg?width=1024&watermark=LYCG_1a',
#  'thumbnail_url_large': 'https://images.autolist.com/image/fetch/s--NNHmBTxL--/c_fill,f_auto,q_auto,w_320/https://img2.carmax.com/img/vehicles/21376192/1.jpg%3Fwidth%3D1024%26watermark%3DLYCG_1a',
#  'lat': 41.871441,
#  'lon': -87.902115,
#  'year': 2016,
#  'make': 'Volkswagen',
#  'model': 'Jetta',
#  'model_id': 1667,
#  'display_color': '',
#  'price': '$15,998',
#  'price_unformatted': 15998,
#  'mileage': '72,457 Miles',
#  'mileage_unformatted': 72457,
#  'city': 'Hillside',
#  'state': 'IL',
#  'distance_from_origin': 1656,
#  'dealer_name': 'CarMax Hillside (Eisenhower Expy) - Now Offering Curbside Pickup',
#  'show_message_box': None,
#  'email_opt_default': True,
#  'show_financing_checkbox': None,
#  'show_new_mileage': False,
#  'show_thankyou_page': False,
#  'show_rsrp': True,
#  'click_off': False,
#  'pre_check_thankyou': True,
#  'cpl_value': 15,
#  'partner_type': 'dealer_direct',
#  'vin': '3VW267AJ5GM298864',
#  'provider': None,
#  'provider_name': 'carmax',
#  'always_ask_for_zip': True,
#  'listing_id': None,
#  'time_on_market': None,
#  'total_price_change': None,
#  'relative_price_difference': None,
#  'listimate_category': None,
#  'listimate_text': None,
#  'photo_urls': [],
#  'tracking_params': {'id_from_provider': '3VW267AJ5GM298864',
#   'remote_dealer_id': '7146',
#   'dealer_name': 'CarMax Hillside (Eisenhower Expy)',
#   'remote_sku': '21376192',
#   'experience': 'national_backfill',
#   'rooftop_unique_name': None,
#   'rooftop_uuid': None,
#   'dealer_unique_name': 'carmax_hillside',
#   'dealer_uuid': '7f5c202a-fc23-45a4-8a79-578a3406e96f',
#   'dealer_group_unique_name': 'carmax',
#   'dealer_group_uuid': 'f6138600-f21e-4c20-90b8-308961c3e520'},
#  'trim': '1.4T S',
#  'provider_id': 146,
#  'provider_group_id': 149,
#  'experience': 'local_if_nearby',
#  'regional': True,
#  'badges': {'position0': None, 'position1': None},
#  'quick_picks_eligible': False}

# %%
# found model data
# encontrado dato del modelo 
results_json['search_results'][0]['model']
# Out:
# 'Jetta'

# %%
# Finding mileage data
# encontrando dato de Kilometraje
results_json['search_results'][0]['mileage']
# Out:
# '72,457 Miles'

# %%
# finding year data
# encontrando dato del año
results_json['search_results'][0]['year']
# Out:
# 2016

# %%
# finding distributor name data
# encontrando dato del nombre de distribuidor
results_json['search_results'][0]['dealer_name']
# Out:
# 'CarMax Hillside (Eisenhower Expy) - Now Offering Curbside Pickup'

# %%
# finding data price
# encontrando datos del precio (dolares)
results_json['search_results'][0]['price']
# Out:
# '$15,998'

# %% [markdown]
# ## Set Paths of Files (Establecer las rutas de los archivos)

# %%
# file used to store all extracted data
# archivo utilizado para almacenar todos los datos extraídos
tmpfile = "data_extracted_temp.tmp"

# all event logs will be stored in this file
# todos los registros de eventos serán almacenados en este archivo
logfile = "dealership_logfile.txt"

# file where transformed data is stored
# archivo donde se almacenan los datos transformados
targetfile = "dealership_transformed_data.csv"

# %% [markdown]
# ## Extract

# %%
# creating a function
# creando una función
def extract():
    
    # create empty lists
    # crear listas vacias
    modelo = []
    kilometraje = []
    año = []
    nom_distribuidor = []
    precio = []

    for result in result_items:
        
        # model (modelo)
        modelo.append(result['model'])
        
        # mileage (kilometraje)
        kilometraje.append(result['mileage'])
        
        # year (año)
        año.append(result['year']) 
        
        # dealer name (nombre de distribuidor)
        nom_distribuidor.append(result['dealer_name']) 
        
        # price (precio)
        precio.append(result['price'])

        # create an empty dataframe to hold extracted data
        # crear un dataframe vacío para contener los datos extraídos
        extracted_data = pd.DataFrame({'Modelo': modelo, 'Kilometraje': kilometraje,
                                    'Año': año, 'Nombre del distribuidor': nom_distribuidor, 'Precio': precio})

    return extracted_data

# %%
extracted_data = extract()
extracted_data.head()
# Out:
#    Modelo   Kilometraje   Año  \
# 0   Jetta  72,457 Miles  2016
# 1   Jetta  78,083 Miles  2016
# 2   Jetta  18,272 Miles  2017
# 3  Passat  77,951 Miles  2017
# 4  Tiguan  29,397 Miles  2018
#
#                              Nombre del distribuidor   Precio
# 0  CarMax Hillside (Eisenhower Expy) - Now Offeri...  $15,998
# 1   CarMax Manchester - Now Offering Curbside Pickup  $17,998
# 2  CarMax Glencoe (Edens Expy) - Now Offering Cur...  $22,998
# 3  CarMax Naples - Now Offering Curbside Pickup A...  $16,998
# 4  CarMax McKinney - Now Offering Curbside Pickup...  $22,998

# %%
extracted_data['Kilometraje'][0].strip(' Miles')
# Out:
# '72,457'

# %%
extracted_data['Kilometraje'][0].strip(' Miles').replace(',', '')
# Out:
# '72457'

# %%
extracted_data['Nombre del distribuidor'][0].split('-')[0]
# Out:
# 'CarMax Hillside (Eisenhower Expy) '

# %% [markdown]
# ## Transfrom

# %% [markdown]
# **Transform data from string to int ,miles to kilometers and split column Distributor name to Distributor and bidding**
#
# Transformar datos de string a int ,millas en kilometros y dividir columna Nombre del distribuidor en Distribuidor y ofertando

# %%
def transform(data):
    # convert miles to kilometers
    # convervir millas a kilometros
    without_miles = lambda x : x.strip(' Miles').replace(',', '')
    data['Kilometraje'] = data['Kilometraje'].apply(without_miles)
    data['Kilometraje'] = data['Kilometraje'].apply(lambda km: float(km) * 1.609)
    
    # split column 'Distributor name
    # dividir columna 'Nombre de distribuidor'
    data['Ubicación de Distribuior'] = data['Nombre del distribuidor'].apply( lambda col: col.split('-')[0])
    data['Oferta de Distribuidor'] = data['Nombre del distribuidor'].apply( lambda col: col.split('-')[1])
    data.drop(['Nombre del distribuidor'], axis=1, inplace = True)
    return data

# %%
td = transform(extracted_data)
td.head()
# Out:
#    Modelo  Kilometraje   Año   Precio            Ubicación de Distribuior  \
# 0   Jetta   116583.313  2016  $15,998  CarMax Hillside (Eisenhower Expy)
# 1   Jetta   125635.547  2016  $17,998                  CarMax Manchester
# 2   Jetta    29399.648  2017  $22,998        CarMax Glencoe (Edens Expy)
# 3  Passat   125423.159  2017  $16,998                      CarMax Naples
# 4  Tiguan    47299.773  2018  $22,998                    CarMax McKinney
#
#                             Oferta de Distribuidor
# 0                     Now Offering Curbside Pickup
# 1                     Now Offering Curbside Pickup
# 2                     Now Offering Curbside Pickup
# 3   Now Offering Curbside Pickup And Home Delivery
# 4   Now Offering Curbside Pickup And Home Delivery

# %% [markdown]
# ## Loading

# %%
def load(targetfile, data_to_load):
    data_to_load.to_csv(targetfile)

# %% [markdown]
# ## Logging

# %%
# change the name of the logfile to the one specified in the set paths section.
# change the timestamp order to Hour-Minute-Second-Monthname-Day-Year.
# cambiar el nombre del archivo de registro al especificado en la sección de rutas
# Cambiar el orden del timestamp a Hora-Minuto-Segundo-Nombre-Día-Año.)
def log(message):
    ## Hour-Minute-Second-MonthName-Day-Year
    # (Hora-Minuto-Segundo-NombreDeMes-Día-Año)
    timestamp_format = '%H:%M:%S-%h-%d-%Y'

    ## get current timestamp
    # (obtener el timestamp actual)
    now = datetime.now()

    timestamp = now.strftime(timestamp_format)

# se crea un nuevo archivo dealership_logifile que almacena el timestamp y el message
    with open("dealership_logfile.txt", "a") as f:
        f.write(timestamp + ',' + message + '\n')

# %% [markdown]
# ## Running ETL Process (Corriendo Proceso ETL)

# %% [markdown]
# **Log that you have started the ETL process**
#
# Registrar que ha iniciado el proceso ETL

# %%
log("ETL Process Job Started, Inicio de Proceso ETL") # parameter message

# call the extract function
# llamar a la función de extracción
extracted_data = extract()

# Log that you have completed the Extract phase
# Registrar que ha completado la fase de Extracción
log("Extract phase Ended, fase de extraccion finalizada") # parameter message

# %% [markdown]
# **checking the extraction phase**
#
# comprobando la fase de extracción

# %%
extracted_data.head()
# Out:
#    Modelo   Kilometraje   Año  \
# 0   Jetta  72,457 Miles  2016
# 1   Jetta  78,083 Miles  2016
# 2   Jetta  18,272 Miles  2017
# 3  Passat  77,951 Miles  2017
# 4  Tiguan  29,397 Miles  2018
#
#                              Nombre del distribuidor   Precio
# 0  CarMax Hillside (Eisenhower Expy) - Now Offeri...  $15,998
# 1   CarMax Manchester - Now Offering Curbside Pickup  $17,998
# 2  CarMax Glencoe (Edens Expy) - Now Offering Cur...  $22,998
# 3  CarMax Naples - Now Offering Curbside Pickup A...  $16,998
# 4  CarMax McKinney - Now Offering Curbside Pickup...  $22,998

# %% [markdown]
# **Log that you have started the Transform phase**
#
# Registrar que ha iniciado la fase de Transformación

# %%
log("Transform phase Started, Fase de tranformacion iniciada")

# Call the transform function
# Llama a la función de transformación
transformed_data = transform(extracted_data)

# Log that you have completed the Transform phase
# Registrar que se ha completado la fase de Transformación
log("Transform phase Ended, Fase de transformación finalizada")

# %% [markdown]
# **checking the transformation phase**
#
# comprobando la fase de transformación

# %%
transformed_data.head()
# Out:
#    Modelo  Kilometraje   Año   Precio            Ubicación de Distribuior  \
# 0   Jetta   116583.313  2016  $15,998  CarMax Hillside (Eisenhower Expy)
# 1   Jetta   125635.547  2016  $17,998                  CarMax Manchester
# 2   Jetta    29399.648  2017  $22,998        CarMax Glencoe (Edens Expy)
# 3  Passat   125423.159  2017  $16,998                      CarMax Naples
# 4  Tiguan    47299.773  2018  $22,998                    CarMax McKinney
#
#                             Oferta de Distribuidor
# 0                     Now Offering Curbside Pickup
# 1                     Now Offering Curbside Pickup
# 2                     Now Offering Curbside Pickup
# 3   Now Offering Curbside Pickup And Home Delivery
# 4   Now Offering Curbside Pickup And Home Delivery

# %% [markdown]
# **checking the load phase**
#
# comprobando la fase de carga

# %%
# Log that you have started the Load step
# Registrar que se ha iniciado el paso de carga
log("Load phase Started, Fase de carga iniciada")

# Call the Load function
# Llamar la función load
load(targetfile, transformed_data)

# Log that you have completed the Load step
# Registrar que ha completado el paso de carga
log("Load phase Ended, Fase de carga finalizada")

# %% [markdown]
# **Log that the ETL process has been completed.**
#
# Registrar que el proceso ETL ha sido completado

# %%
log('ETL Process Ended, Proceso ETL finalizado')

# %% [markdown]
# **Checking that csv file has been created successfully**
#
# Revisando que archivo csv se ha creado satisfactoriamente

# %%
df = pd.read_csv('dealership_transformed_data.csv', index_col=[0])
df.head()
# Out:
#    Modelo  Kilometraje   Año   Precio            Ubicación de Distribuior  \
# 0   Jetta   116583.313  2016  $15,998  CarMax Hillside (Eisenhower Expy)
# 1   Jetta   125635.547  2016  $17,998                  CarMax Manchester
# 2   Jetta    29399.648  2017  $22,998        CarMax Glencoe (Edens Expy)
# 3  Passat   125423.159  2017  $16,998                      CarMax Naples
# 4  Tiguan    47299.773  2018  $22,998                    CarMax McKinney
#
#                             Oferta de Distribuidor
# 0                     Now Offering Curbside Pickup
# 1                     Now Offering Curbside Pickup
# 2                     Now Offering Curbside Pickup
# 3   Now Offering Curbside Pickup And Home Delivery
# 4   Now Offering Curbside Pickup And Home Delivery

# %% [markdown]
# **Review the log file**
#
# Revisar el archivo de registros

# %%
df_logs = pd.read_csv('dealership_logfile.txt', index_col=0, encoding = 'latin-1')
df_logs
# Out:
#                       ETL Process Job Started  \
# 16:30:14-Dec-01-2021
# 16:30:14-Dec-01-2021      Extract phase Ended
# 16:32:36-Dec-01-2021  ETL Process Job Started
# 16:32:36-Dec-01-2021      Extract phase Ended
# 16:41:29-Dec-01-2021  Transform phase Started
# 16:41:29-Dec-01-2021    Transform phase Ended
# 16:45:09-Dec-01-2021  ETL Process Job Started
# 16:45:09-Dec-01-2021      Extract phase Ended
# 16:50:01-Dec-01-2021       Load phase Started
# 16:50:02-Dec-01-2021         Load phase Ended
# 16:53:27-Dec-01-2021        ETL Process Ended
# 17:08:15-Dec-01-2021  Transform phase Started
# 17:08:15-Dec-01-2021    Transform phase Ended
# 17:08:23-Dec-01-2021       Load phase Started
# 17:08:23-Dec-01-2021         Load phase Ended
# 17:08:29-Dec-01-2021        ETL Process Ended
#
#                                    Inicio de Proceso ETL
# 16:30:14-Dec-01-2021
# 16:30:14-Dec-01-2021       fase de extraccion finalizada
# 16:32:36-Dec-01-2021               Inicio de Proceso ETL
# 16:32:36-Dec-01-2021       fase de extraccion finalizada
# 16:41:29-Dec-01-2021      Fase de tranformacion iniciada
# 16:41:29-Dec-01-2021   Fase de transformación finalizada
# 16:45:09-Dec-01-2021               Inicio de Proceso ETL
# 16:45:09-Dec-01-2021       fase de extraccion finalizada
# 16:50:01-Dec-01-2021              Fase de carga iniciada
# 16:50:02-Dec-01-2021            Fase de carga finalizada
# 16:53:27-Dec-01-2021              Proceso ETL finalizado
# 17:08:15-Dec-01-2021      Fase de tranformacion iniciada
# 17:08:15-Dec-01-2021   Fase de transformación finalizada
# 17:08:23-Dec-01-2021              Fase de carga iniciada
# 17:08:23-Dec-01-2021            Fase de carga finalizada
# 17:08:29-Dec-01-2021              Proceso ETL finalizado

# %% [markdown]
# ---

# %% [markdown]
# ## Multi-page Scraping
#
# ## Scraping de Multiples páginas

# %%
# url by calaya
headers = {
    'authority': 'www.autolist.com',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^94^\\^, ^\\^Google',
    'accept': '*/*',
    'x-requested-with': 'XMLHttpRequest',
    'sec-ch-ua-mobile': '?0',
    'x-autolist-session-guid': 'c9fb9ffb-2c06-4468-a3d0-c26290c6994f',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4590.0 Safari/537.36',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-mode': 'cors',
    'sec-fetch-dest': 'empty',
    'referer': 'https://www.autolist.com/listings',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzk0LjAuNDU5MC4wIFNhZmFyaS81MzcuMzYifQ==; client_guid_timestamp=1602952f-d1bf-4936-82e3-cbdedfa11d2d.1627825394925; scavenger-a493=...; _sp_ses.8ca5=*; _gid=GA1.2.96049973.1627825395; _fbp=fb.1.1627825395573.409117512; __gads=ID=c459f8bf6d0987dd:T=1627825394:S=ALNI_MaW1epD3HNJsvJQTCnPWSJCcOdE_w; AMP_TOKEN=^%^24NOT_FOUND; sp-nuid=e4461948-a1a2-45a1-88f8-45c2889d9576; _gcl_au=1.1.519751617.1627825557; _ga_152345333=GS1.1.1627825395.1.1.1627828426.0; _ga=GA1.2.2118379867.1627825395; cto_bundle=WV1etl8zMUc1cGt6WnZNSEZMYWhwNnJjUXpTYzQxVzZ6QzM5VE1tWXZFcjQ3ZWhrNTlETG1CemlUdmNFYUtIbXdCQTNFelJmY3h6QXA0SlVIZml0WVg2OWQxZlBPMmRqbExXNU9XZTM0V0VaR09tbHBvJTJGdERCb21zZUVKJTJCTG1vVzlDV0w2VjA0bDklMkJnRjdrMmZPUExmJTJGY0l6USUzRCUzRA; _gat=1; _sp_id.8ca5=d3d3f60d-371c-4289-92fe-1c6f66b4979f.1627825395.1.1627828912.1627825395.8bc1e545-8ca1-448e-b1ba-ec8d2c359ada',
    'if-none-match': 'W/^\\^c6f72fa4ef059e03ea0309ebd57c197d^\\^',
}

url = "https://www.autolist.com/api/cwv/seo/listings?make=Volkswagen&location=Celaya,%20Gto.&latitude=20.5135374&longitude=-100.8160686&radius=50&page=1"

response = requests.get(url, headers=headers)

modelo = []
kilometraje = []
año = []
nom_distribuidor = []
precio = []

# 5 paginas
for i in range(1,6):

    """params = (
        ('make', 'Tesla'),
        ('location', 'San^%^20Francisco,^%^20CA'),
        ('latitude', '37.7749295'),
        ('longitude', '-122.4194155'),
        ('radius', '50'),
        ('page', str(i)),
    )"""
    
    
    # json object
    results_json = response.json()
    
    # result items (20 items por cada pagina)
    result_items = results_json['search_results']
    
    for result in result_items:
        modelo.append(result['model'])
        kilometraje.append(result['mileage'])
        año.append(result['year']) 
        nom_distribuidor.append(result['dealer_name']) 
        precio.append(result['price'])

# %%
multiple_df = pd.DataFrame({'Modelo': modelo, 'Kilometraje':kilometraje, 'Año':año, 
                            'Nom_distribuidor': nom_distribuidor, 'Precio': precio})

# %%
multiple_df
# Out:
#     Modelo   Kilometraje   Año  \
# 0   Golf R  54,682 Miles  2016
# 1    Jetta  43,183 Miles  2017
# 2    Jetta  87,585 Miles  2015
# 3   Passat  64,144 Miles  2016
# 4    Jetta  46,804 Miles  2017
# ..     ...           ...   ...
# 95  Tiguan  28,934 Miles  2019
# 96  Tiguan  10,391 Miles  2018
# 97   Jetta  48,183 Miles  2019
# 98   Jetta  40,448 Miles  2017
# 99  Tiguan   8,757 Miles  2020
#
#                                      Nom_distribuidor   Precio
# 0                CarMax Capitol Expressway - Now Open  $31,998
# 1   CarMax Brooklyn Park - Now Offering Curbside P...  $18,998
# 2   CarMax Plano - Now Offering Curbside Pickup An...  $14,998
# 3   CarMax Ft. Lauderdale - Now Offering Curbside ...  $16,998
# 4         CarMax Omaha - Now Offering Curbside Pickup  $17,998
# ..                                                ...      ...
# 95  CarMax South Boulevard - Now Offering Curbside...  $23,998
# 96  CarMax Capital Boulevard - Now Offering Curbsi...  $31,998
# 97  CarMax LAX - Now Offering Curbside Pickup And ...  $20,998
# 98    CarMax Beaverton - Now Offering Curbside Pickup  $19,998
# 99  CarMax South Boulevard - Now Offering Curbside...  $39,998
#
# [100 rows x 5 columns]

# %% [markdown]
# #### Crear archivo csv y almacenar los datos

# %%
multiple_df.to_csv('volkswagen_multiple_pages.csv', index=False)

# %%
# revisar el csv creado
pd.read_csv('volkswagen_multiple_pages.csv')
# Out:
#     Modelo   Kilometraje   Año  \
# 0    Jetta  43,183 Miles  2017
# 1   Golf R  54,682 Miles  2016
# 2    Jetta  87,585 Miles  2015
# 3   Passat  64,144 Miles  2016
# 4   Tiguan  28,959 Miles  2018
# ..     ...           ...   ...
# 95  Tiguan  28,934 Miles  2019
# 96   Jetta  48,183 Miles  2019
# 97  Tiguan  10,391 Miles  2018
# 98   Jetta  40,448 Miles  2017
# 99  Tiguan   8,757 Miles  2020
#
#                                      Nom_distribuidor   Precio
# 0   CarMax Brooklyn Park - Now Offering Curbside P...  $18,998
# 1                CarMax Capitol Expressway - Now Open  $31,998
# 2   CarMax Plano - Now Offering Curbside Pickup An...  $14,998
# 3   CarMax Ft. Lauderdale - Now Offering Curbside ...  $16,998
# 4   CarMax Killeen - Now Offering Curbside Pickup ...  $21,998
# ..                                                ...      ...
# 95  CarMax South Boulevard - Now Offering Curbside...  $23,998
# 96  CarMax LAX - Now Offering Curbside Pickup And ...  $20,998
# 97  CarMax Capital Boulevard - Now Offering Curbsi...  $31,998
# 98    CarMax Beaverton - Now Offering Curbside Pickup  $19,998
# 99  CarMax South Boulevard - Now Offering Curbside...  $39,998
#
# [100 rows x 5 columns]

# %%
import pymysql

# %%
# creando connecion con mysql
conn = pymysql.connect(database= 'autolist_volkswagen', user= 'root', password= 'dadax_0331//_1330')

# %%
# creando cursor
cursor = conn.cursor()

# %%
# probando conceccion la base de datos
cursor.execute('SELECT * FROM cars_volkswagen_celaya')
# Out:
# 0

# %% [markdown]
# **creando INSERT TO statement**

# %%
insert_query = 'INSERT INTO cars_volkswagen_celaya VALUES '

# %%
insert_query
# Out:
# 'INSERT INTO cars_volkswagen_celaya VALUES '

# %%
# 100 filas 5 columnas
multiple_df.shape
# Out:
# (100, 5)

# %%
multiple_df.columns.values
# Out:
# array(['Modelo', 'Kilometraje', 'Año', 'Nom_distribuidor', 'Precio'],
#       dtype=object)

# %%
multiple_df.columns.values[3]
# Out:
# 'Nom_distribuidor'

# %%
multiple_df['Nom_distribuidor']
# Out:
# 0                  CarMax Capitol Expressway - Now Open
# 1     CarMax Brooklyn Park - Now Offering Curbside P...
# 2     CarMax Plano - Now Offering Curbside Pickup An...
# 3     CarMax Ft. Lauderdale - Now Offering Curbside ...
# 4           CarMax Omaha - Now Offering Curbside Pickup
#                             ...
# 95    CarMax South Boulevard - Now Offering Curbside...
# 96    CarMax Capital Boulevard - Now Offering Curbsi...
# 97    CarMax LAX - Now Offering Curbside Pickup And ...
# 98      CarMax Beaverton - Now Offering Curbside Pickup
# 99    CarMax South Boulevard - Now Offering Curbside...
# Name: Nom_distribuidor, Length: 100, dtype: object

# %%
# revisando los valores correctos
multiple_df['Nom_distribuidor'][0]
# Out:
# 'CarMax Capitol Expressway - Now Open'

# %%
# creando los valores de la query INSERT TO
for i in range(multiple_df.shape[0]):
    insert_query += '('
    
    for j in range(multiple_df.shape[1]):
        insert_query += str(multiple_df[multiple_df.columns.values[j]][i]) + ', ' + '/n'
        
    insert_query = insert_query[:-2] + '), '

# %%
insert_query
# Out:
# 'INSERT INTO cars_volkswagen_celaya VALUES (Golf R, 54,682 Miles, 2016, CarMax Capitol Expressway - Now Open, $31,998), (Jetta, 43,183 Miles, 2017, CarMax Brooklyn Park - Now Offering Curbside Pickup, $18,998), (Jetta, 87,585 Miles, 2015, CarMax Plano - Now Offering Curbside Pickup And Home Delivery, $14,998), (Passat, 64,144 Miles, 2016, CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery, $16,998), (Jetta, 46,804 Miles, 2017, CarMax Omaha - Now Offering Curbside Pickup, $17,998), (Tiguan, 28,959 Miles, 2018, CarMax Killeen - Now Offering Curbside Pickup And Home Delivery, $21,998), (Touareg, 53,590 Miles, 2017, CarMax Rivergate - Now Offering Curbside Pickup, $31,998), (Passat, 40,191 Miles, 2016, CarMax Cool Springs - Now Offering Curbside Pickup, $18,998), (Jetta, 62,366 Miles, 2016, CarMax Lynnwood - Now Offering Curbside Pickup, $15,998), (Jetta, 69,527 Miles, 2014, CarMax Clearwater - Now Offering Curbside Pickup And Home Delivery, $14,599), (Golf R, 9,886 Miles, 2019, CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery, $44,998), (Jetta, 14,970 Miles, 2019, CarMax South Broadway - Now Offering Curbside Pickup And Home Delivery, $19,998), (Jetta, 22,769 Miles, 2019, CarMax Westborough - Now Offering Curbside Pickup, $19,998), (Golf SportWagen, 15,234 Miles, 2018, CarMax Salem - Now Offering Curbside Pickup, $24,998), (Arteon, 12,138 Miles, 2019, CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery, $29,998), (Tiguan, 28,934 Miles, 2019, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $23,998), (Tiguan, 10,391 Miles, 2018, CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery, $31,998), (Jetta, 48,183 Miles, 2019, CarMax LAX - Now Offering Curbside Pickup And Home Delivery, $20,998), (Jetta, 40,448 Miles, 2017, CarMax Beaverton - Now Offering Curbside Pickup, $19,998), (Tiguan, 8,757 Miles, 2020, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $39,998), (Golf R, 54,682 Miles, 2016, CarMax Capitol Expressway - Now Open, $31,998), (Jetta, 43,183 Miles, 2017, CarMax Brooklyn Park - Now Offering Curbside Pickup, $18,998), (Jetta, 87,585 Miles, 2015, CarMax Plano - Now Offering Curbside Pickup And Home Delivery, $14,998), (Passat, 64,144 Miles, 2016, CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery, $16,998), (Jetta, 46,804 Miles, 2017, CarMax Omaha - Now Offering Curbside Pickup, $17,998), (Tiguan, 28,959 Miles, 2018, CarMax Killeen - Now Offering Curbside Pickup And Home Delivery, $21,998), (Touareg, 53,590 Miles, 2017, CarMax Rivergate - Now Offering Curbside Pickup, $31,998), (Passat, 40,191 Miles, 2016, CarMax Cool Springs - Now Offering Curbside Pickup, $18,998), (Jetta, 62,366 Miles, 2016, CarMax Lynnwood - Now Offering Curbside Pickup, $15,998), (Jetta, 69,527 Miles, 2014, CarMax Clearwater - Now Offering Curbside Pickup And Home Delivery, $14,599), (Golf R, 9,886 Miles, 2019, CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery, $44,998), (Jetta, 14,970 Miles, 2019, CarMax South Broadway - Now Offering Curbside Pickup And Home Delivery, $19,998), (Jetta, 22,769 Miles, 2019, CarMax Westborough - Now Offering Curbside Pickup, $19,998), (Golf SportWagen, 15,234 Miles, 2018, CarMax Salem - Now Offering Curbside Pickup, $24,998), (Arteon, 12,138 Miles, 2019, CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery, $29,998), (Tiguan, 28,934 Miles, 2019, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $23,998), (Tiguan, 10,391 Miles, 2018, CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery, $31,998), (Jetta, 48,183 Miles, 2019, CarMax LAX - Now Offering Curbside Pickup And Home Delivery, $20,998), (Jetta, 40,448 Miles, 2017, CarMax Beaverton - Now Offering Curbside Pickup, $19,998), (Tiguan, 8,757 Miles, 2020, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $39,998), (Golf R, 54,682 Miles ...

# %%
insert_query = insert_query[:-2] + ';'

# %%
insert_query
# Out:
# 'INSERT INTO cars_volkswagen_celaya VALUES (Golf R, 54,682 Miles, 2016, CarMax Capitol Expressway - Now Open, $31,998), (Jetta, 43,183 Miles, 2017, CarMax Brooklyn Park - Now Offering Curbside Pickup, $18,998), (Jetta, 87,585 Miles, 2015, CarMax Plano - Now Offering Curbside Pickup And Home Delivery, $14,998), (Passat, 64,144 Miles, 2016, CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery, $16,998), (Jetta, 46,804 Miles, 2017, CarMax Omaha - Now Offering Curbside Pickup, $17,998), (Tiguan, 28,959 Miles, 2018, CarMax Killeen - Now Offering Curbside Pickup And Home Delivery, $21,998), (Touareg, 53,590 Miles, 2017, CarMax Rivergate - Now Offering Curbside Pickup, $31,998), (Passat, 40,191 Miles, 2016, CarMax Cool Springs - Now Offering Curbside Pickup, $18,998), (Jetta, 62,366 Miles, 2016, CarMax Lynnwood - Now Offering Curbside Pickup, $15,998), (Jetta, 69,527 Miles, 2014, CarMax Clearwater - Now Offering Curbside Pickup And Home Delivery, $14,599), (Golf R, 9,886 Miles, 2019, CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery, $44,998), (Jetta, 14,970 Miles, 2019, CarMax South Broadway - Now Offering Curbside Pickup And Home Delivery, $19,998), (Jetta, 22,769 Miles, 2019, CarMax Westborough - Now Offering Curbside Pickup, $19,998), (Golf SportWagen, 15,234 Miles, 2018, CarMax Salem - Now Offering Curbside Pickup, $24,998), (Arteon, 12,138 Miles, 2019, CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery, $29,998), (Tiguan, 28,934 Miles, 2019, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $23,998), (Tiguan, 10,391 Miles, 2018, CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery, $31,998), (Jetta, 48,183 Miles, 2019, CarMax LAX - Now Offering Curbside Pickup And Home Delivery, $20,998), (Jetta, 40,448 Miles, 2017, CarMax Beaverton - Now Offering Curbside Pickup, $19,998), (Tiguan, 8,757 Miles, 2020, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $39,998), (Golf R, 54,682 Miles, 2016, CarMax Capitol Expressway - Now Open, $31,998), (Jetta, 43,183 Miles, 2017, CarMax Brooklyn Park - Now Offering Curbside Pickup, $18,998), (Jetta, 87,585 Miles, 2015, CarMax Plano - Now Offering Curbside Pickup And Home Delivery, $14,998), (Passat, 64,144 Miles, 2016, CarMax Ft. Lauderdale - Now Offering Curbside Pickup And Home Delivery, $16,998), (Jetta, 46,804 Miles, 2017, CarMax Omaha - Now Offering Curbside Pickup, $17,998), (Tiguan, 28,959 Miles, 2018, CarMax Killeen - Now Offering Curbside Pickup And Home Delivery, $21,998), (Touareg, 53,590 Miles, 2017, CarMax Rivergate - Now Offering Curbside Pickup, $31,998), (Passat, 40,191 Miles, 2016, CarMax Cool Springs - Now Offering Curbside Pickup, $18,998), (Jetta, 62,366 Miles, 2016, CarMax Lynnwood - Now Offering Curbside Pickup, $15,998), (Jetta, 69,527 Miles, 2014, CarMax Clearwater - Now Offering Curbside Pickup And Home Delivery, $14,599), (Golf R, 9,886 Miles, 2019, CarMax West Sahara - Now Offering Curbside Pickup And Home Delivery, $44,998), (Jetta, 14,970 Miles, 2019, CarMax South Broadway - Now Offering Curbside Pickup And Home Delivery, $19,998), (Jetta, 22,769 Miles, 2019, CarMax Westborough - Now Offering Curbside Pickup, $19,998), (Golf SportWagen, 15,234 Miles, 2018, CarMax Salem - Now Offering Curbside Pickup, $24,998), (Arteon, 12,138 Miles, 2019, CarMax Costa Mesa - Now Offering Curbside Pickup And Home Delivery, $29,998), (Tiguan, 28,934 Miles, 2019, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $23,998), (Tiguan, 10,391 Miles, 2018, CarMax Capital Boulevard - Now Offering Curbside Pickup And Home Delivery, $31,998), (Jetta, 48,183 Miles, 2019, CarMax LAX - Now Offering Curbside Pickup And Home Delivery, $20,998), (Jetta, 40,448 Miles, 2017, CarMax Beaverton - Now Offering Curbside Pickup, $19,998), (Tiguan, 8,757 Miles, 2020, CarMax South Boulevard - Now Offering Curbside Pickup And Home Delivery, $39,998), (Golf R, 54,682 Miles ...

# %%
# ingresando la query a la base de datos
cursor.execute(insert_query)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# <ipython-input-72-fef8f19cda10> in <module>
#       1 # ingresando la query a la base de datos
# ----> 2 cursor.execute(insert_query)
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# ~\anaconda3\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# ~\anaconda3\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# ~\anaconda3\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# ~\anaconda3\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# ProgrammingError: (1064, "You have an error in your SQL syntax; check the manual that corresponds to your MySQL server version for the right syntax to use near 'R, 54,682 Miles, 2016, CarMax Capitol Expressway - Now Open, $31,998), (Jetta, 4' at line 1")

# %%
conn.commit()

# %%
conn.close()
